# %%
pip install -U pytest
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.2/375.2 kB 7.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pytest
#     Found existing installation: pytest 8.4.2
#     Uninstalling pytest-8.4.2:
#       Successfully uninstalled pytest-8.4.2
# ...

# %%
# !pytest --version
# Out:
# pytest 9.0.3

# %%
# !mkdir -p tests

# %%
# %%writefile tests/test_cases.md
# # GTM Scoring Test Cases
#
# Six edge-case vectors for validating the scoring formula.
#
# ## Case 1 — Strong Demand, Weak Conversion, Mid Delivery
# - Demand avg: 4.5
# - Conversion avg: 2.0
# - Delivery avg: 3.0
#
# ## Case 2 — Weak Demand, Strong Conversion, Mid Delivery
# - Demand avg: 2.0
# - Conversion avg: 4.5
# - Delivery avg: 3.0
#
# ## Case 3 — All Strong
# - Demand avg: 4.5
# - Conversion avg: 4.5
# - Delivery avg: 4.5
#
# ## Case 4 — All Weak
# - Demand avg: 1.5
# - Conversion avg: 1.5
# - Delivery avg: 1.5
#
# ## Case 5 — Mid Demand, Mid Conversion, Weak Delivery
# - Demand avg: 3.0
# - Conversion avg: 3.0
# - Delivery avg: 2.0
#
# ## Case 6 — Ardent SA's exact live scores
# - Source: pull from live AssessmentSession (TM2 to provide UUID)
# - Demand avg: 2.86
# - Conversion avg: 2.99
# - Delivery avg: 3.32
# Out:
# Writing tests/test_cases.md

# %%
# !cat tests/test_cases.md
# Out:
# # GTM Scoring Test Cases
#
# Six edge-case vectors for validating the scoring formula.
#
# ## Case 1 — Strong Demand, Weak Conversion, Mid Delivery
# - Demand avg: 4.5
# - Conversion avg: 2.0
# - Delivery avg: 3.0
#
# ## Case 2 — Weak Demand, Strong Conversion, Mid Delivery
# - Demand avg: 2.0
# - Conversion avg: 4.5
# - Delivery avg: 3.0
#
# ## Case 3 — All Strong
# - Demand avg: 4.5
# - Conversion avg: 4.5
# - Delivery avg: 4.5
#
# ## Case 4 — All Weak
# - Demand avg: 1.5
# - Conversion avg: 1.5
# - Delivery avg: 1.5
#
# ## Case 5 — Mid Demand, Mid Conversion, Weak Delivery
# - Demand avg: 3.0
# - Conversion avg: 3.0
# - Delivery avg: 2.0
#
# ## Case 6 — Ardent SA's exact live scores
# - Source: pull from live AssessmentSession (TM2 to provide UUID)
# - TODO: populate once TM2 shares the session data
